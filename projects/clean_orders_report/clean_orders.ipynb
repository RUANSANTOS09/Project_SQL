# %%
import pandas as pd
import mysql.connector as mysql

# %%
connection = mysql.connect(
    host="localhost",
    user="root",
    passwd="Ruan81527733",
    database="ecommerce",
)

df = pd.read_sql("SELECT * FROM orders", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_11952\1474690492.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM orders", connection)

# %%
mapping = {
    'coupon_code': 'Sem cupom',
    'delivery_date' : 'Pedido ainda não entregue',
    'reason_for_cancellation' : 'Pedido não cancelado'
}
df = df.fillna(mapping)
df
# Out:
#    orders_id  customer_id        status coupon_code  order_date  \
# 0         10            1    Finalizada   Sem cupom  2025-06-01
# 1         11            3  Em andamento   Sem cupom  2025-08-01
# 2         12            2     Cancelada   Sem cupom  2025-06-01
# 3         13            2    Finalizada   Sem cupom  2026-02-06
# 4         14            7    Finalizada   Sem cupom  2025-06-01
# 5         15            9    Finalizada   Sem cupom  2025-06-01
# 6         16            5    Finalizada   Sem cupom  2025-06-01
# 7         17            6    Finalizada   Sem cupom  2025-06-11
# 8         18            8    Finalizada   Sem cupom  2025-06-11
#
#                delivery_date reason_for_cancellation
# 0                 2025-07-01    Pedido não cancelado
# 1  Pedido ainda não entregue    Pedido não cancelado
# 2  Pedido ainda não entregue          Falta de Saldo
# 3                 2026-03-06    Pedido não cancelado
# 4                 2025-07-01    Pedido não cancelado
# 5                 2025-07-01    Pedido não cancelado
# 6                 2025-07-01    Pedido não cancelado
# 7                 2025-07-11    Pedido não cancelado
# 8                 2026-07-01    Pedido não cancelado

# %%
df.isnull().sum()
# Out:
# orders_id                  0
# customer_id                0
# status                     0
# coupon_code                0
# order_date                 0
# delivery_date              0
# reason_for_cancellation    0
# dtype: int64
