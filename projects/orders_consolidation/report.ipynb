# %%
import pandas as pd
import mysql.connector as sql
import os

# %%
connection = sql.connect(
    host="localhost",
    user="root",
    passwd="Ruan81527733",
    database="ecommerce",
)

# %%
df_finished = pd.read_sql("SELECT * FROM orders WHERE status = 'Finalizada'", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_14004\3039755647.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_finished = pd.read_sql("SELECT * FROM orders WHERE status = 'Finalizada'", connection)

# %%
df_in_progress = pd.read_sql("SELECT * FROM orders WHERE status = 'Em andamento'", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_14004\3360533187.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_in_progress = pd.read_sql("SELECT * FROM orders WHERE status = 'Em andamento'", connection)

# %%
df_canceled = pd.read_sql("SELECT * FROM orders WHERE status = 'Cancelada'", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_14004\2382811666.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_canceled = pd.read_sql("SELECT * FROM orders WHERE status = 'Cancelada'", connection)

# %%
consolidated_orders_report = pd.concat([df_finished, df_in_progress, df_canceled], ignore_index=True)

# %%
destination_folder = r'C:\Users\ruans\Project_SQL\projects\orders_consolidation\Pasta_arquivo_consolidado'

filename = 'order.csv'

folder_path = os.path.join(destination_folder, filename)

consolidated_orders_report.to_csv(folder_path, index=False, sep=',')

# %%
pd.read_csv(folder_path)
# Out:
#    orders_id  customer_id        status  coupon_code  order_date  \
# 0         10            1    Finalizada          NaN  2025-06-01
# 1         13            2    Finalizada          NaN  2026-02-06
# 2         14            7    Finalizada          NaN  2025-06-01
# 3         15            9    Finalizada          NaN  2025-06-01
# 4         16            5    Finalizada          NaN  2025-06-01
# 5         17            6    Finalizada          NaN  2025-06-11
# 6         18            8    Finalizada          NaN  2025-06-11
# 7         11            3  Em andamento          NaN  2025-08-01
# 8         12            2     Cancelada          NaN  2025-06-01
#
#   delivery_date reason_for_cancellation
# 0    2025-07-01                     NaN
# 1    2026-03-06                     NaN
# 2    2025-07-01                     NaN
# 3    2025-07-01                     NaN
# 4    2025-07-01                     NaN
# 5    2025-07-11                     NaN
# ...
